# %%
import xml.etree.ElementTree as ET
from IPython.core.display import Image, display
tree = ET.parse('productLog.xml')
root = tree.getroot()


for child in root:
    if 'name' in child.attrib:
        print child.attrib['name']
        if child.tag == 'statistics':
            for cx in child:
                if cx.text:
                    print cx.attrib['name'],': ',cx.text
                else:
                    print cx.attrib['name']
            
        elif child.tag == 'plot':
        
            print child[1].text

            display(Image(filename=child[0].text))
                        
            print child[2].text
            
        else:
            for ch in child:
                if 'name' in ch.attrib:
                    print ch.attrib['name']
                    if ch.tag == 'statistics':
                        for cx in ch:
                            if cx.text:
                                print cx.attrib['name'],': ',cx.text
                            else:
                                print cx.attrib['name']
                    
                    elif ch.tag == 'plot':
                        print ch[1].text

                        display(Image(filename=ch[0].text))
                        
                        print ch[2].text
                        
                    else:

                        for c in ch:
                            if c.tag == 'statistics':
                                for cx in c:
                                    if cx.text:
                                        print cx.attrib['name'],': ',cx.text
                                    else:
                                        print cx.attrib['name']
                            elif c.tag == 'plot':
                                print c[1].text

                                display(Image(filename=c[0].text))
                        
                                print c[2].text
                        
                            else:
                                print c.tag, ': ', c.attrib['name']
                                for cd in c:
                                    if cd.tag == 'plot':
                                        display(Image(filename=cd[0].text))
                                    elif cd.tag == 'statistics':
                                        for ds in cd:
                                            if ds.text:
                                                print ds.attrib['name'],': ',ds.text
                                            else:
                                                print ds.attrib['name']
                                #display(Image(filename=c[0].text))
# Out:
# Photo-z Training
# Summary
# Subsets Separation
# General
# filter :  Data
# Data Source
# Catalog :  Cross match from spec and photo
# Photometry
# Apply weights :  yes
# Magnitude Type for weights :  auto
# Number of bands :  4
# Number of Objects
# Whole Training Set (before cuts) :  160299
# Whole Training Set (after cuts) :  160299
# Percentage cut :  0.0
# Fraction of whole set for training subset :  0.6
# Fraction of whole set for validation subset :  1.0
# Training Subset :  96179
# Validation Subset :  64120
# Photometric Set (before cuts) :  641196
# Photometric Set (after cuts) :  225005
# Percentage cut :  64.9
# Redshift Range - Training Subset
# average :  0.6049
# median :  0.5842
# minimum :  0.0010
# maximum :  7.0112
# Redshift Range - Validation Subset
# average :  0.7885
# median :  0.7774
# minimum :  0.0010
# maximum :  6.8696
# filter :  Data Selection
# Redshift Range Cut
# z min :  0.0000
# z max :  2.0000
# Magnitude used for cut :  auto
# Signal-to-noise Cut
# g :  None
# r :  None
# i :  None
# z :  None
# Y :  None
# Magnitude Limit Cut
# g :  None
# r :  None
# i :  22.5
# z :  None
# Y :  None
# Weights
# filter :
# Apply weights :  yes
# Weights only in validation :
# Size of virtual weighted set (how many times the main set size, when repeating objects) :  10.0
# Size of final weighted set (after random sampling in virtual set) :  1.0
# Observabes used to compute weights :  colors2
# Number of nearest neighbors uset to compute weights :  5
# Photo-z Training
# Training Files
# filter :
# Code :  training files created
# MLZ :  mlz_trees.tar
# Annz2 :  annz2_training.tar
# Lephare :  lephare_shifts.txt
# Code :  Duration
# MLZ :  345.447 minutes
# Annz2 :  414.213 minutes
# Lephare :  91.358 minutes
# Code :  Magnitude type
# Annz2 :  auto
# BPZ :  auto
# LePhare :  auto
# MLZ :  auto
# LePhare's calibration
# filter :
# SHIFTS :   -0.030,-0.003,0.001,0.028,
#
# MLZ
# Metrics MLZ
# filter :  Global Metrics MLZ
# Bias Mean :  -0.0097
# Bias Median :  -0.0015
# Sigma :  0.1627
# Sigma68 :  0.0858
# Frac 2 :  0.0194
# Frac 3 :  0.0080
# Bias norm :  -0.1200
# Sigma norm :  2.1114
# N Poisson :  23.4614
# filter :  Metric Plots MLZ
# Validation Plots MLZ
# filter :  Validation Plots MLZ
# LePhare
# Metrics LePhare
# filter :  Global Metrics LePhare
# Bias Mean :  -0.0117
# Bias Median :  -0.0084
# Sigma :  0.1718
# Sigma68 :  0.0956
# Frac 2 :  0.0221
# Frac 3 :  0.0088
# Bias norm :  -0.0958
# Sigma norm :  3.0045
# N Poisson :  11.1738
# filter :  Metric Plots LePhare
# Validation Plots LePhare
# filter :  Validation Plots LePhare
# ANNz2
# Metrics ANNz2
# filter :  Global Metrics ANNz2
# Bias Mean :  -0.0001
# Bias Median :  0.0044
# Sigma :  0.1630
# Sigma68 :  0.0871
# Frac 2 :  0.0187
# Frac 3 :  0.0079
# Bias norm :  -0.0194
# Sigma norm :  2.5408
# N Poisson :  20.5340
# filter :  Metric Plots ANNz2
# Validation Plots ANNz2
# filter :  Validation Plots ANNz2
# Comparison
# Metrics
# filter :  Bias Mean
# MLZ :  -0.0097
# BPZ :  -0.0117
# Annz2 :  -0.0001
# filter :  Sigma68
# MLZ :  0.0858
# BPZ :  0.0956
# Annz2 :  0.0871
# filter :  Frac above 2sigma
# MLZ :  0.0194
# BPZ :  0.0221
# Annz2 :  0.0187
# filter :  N Poisson
# MLZ :  23.4614
# BPZ :  11.1738
# Annz2 :  20.5340
# Plots
# filter :  Redshift histograms
# filter :  Photo-z vs. Spec-z scatter
# filter :  Photo-z vs. Spec-z density
