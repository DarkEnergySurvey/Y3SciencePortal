# %%
import xml.etree.ElementTree as ET
from IPython.core.display import Image, display
tree = ET.parse('productLog.xml')
root = tree.getroot()


for child in root:
    if 'name' in child.attrib:
        print child.attrib['name']
        if child.tag == 'statistics':
            for cx in child:
                if cx.text:
                    print cx.attrib['name'],': ',cx.text
                else:
                    print cx.attrib['name']
            
        elif child.tag == 'plot':
        
            print child[1].text

            display(Image(filename=child[0].text))
                        
            print child[2].text
            
        else:
            for ch in child:
                if 'name' in ch.attrib:
                    print ch.attrib['name']
                    if ch.tag == 'statistics':
                        for cx in ch:
                            if cx.text:
                                print cx.attrib['name'],': ',cx.text
                            else:
                                print cx.attrib['name']
                    
                    elif ch.tag == 'plot':
                        print ch[1].text

                        display(Image(filename=ch[0].text))
                        
                        print ch[2].text
                        
                    else:

                        for c in ch:
                            if c.tag == 'statistics':
                                for cx in c:
                                    if cx.text:
                                        print cx.attrib['name'],': ',cx.text
                                    else:
                                        print cx.attrib['name']
                            elif c.tag == 'plot':
                                print c[1].text

                                display(Image(filename=c[0].text))
                        
                                print c[2].text
                        
                            else:
                                print c.tag, ': ', c.attrib['name']
                                for cd in c:
                                    if cd.tag == 'plot':
                                        display(Image(filename=cd[0].text))
                                    elif cd.tag == 'statistics':
                                        for ds in cd:
                                            if ds.text:
                                                print ds.attrib['name'],': ',ds.text
                                            else:
                                                print ds.attrib['name']
                                #display(Image(filename=c[0].text))
# Out:
# Photo-z Training
# Summary
# Subsets Separation
# General
# filter :  Data
# Data Source
# Catalog :  Cross match from spec and photo
# Photometry
# Apply weights :  yes
# Magnitude Type for weights :  auto
# Number of bands :  4
# Number of Objects
# Whole Training Set (before cuts) :  160299
# Whole Training Set (after cuts) :  160299
# Percentage cut :  0.0
# Fraction of whole set for training subset :  0.6
# Fraction of whole set for validation subset :  1.0
# Training Subset :  96179
# Validation Subset :  64120
# Photometric Set (before cuts) :  641196
# Photometric Set (after cuts) :  224853
# Percentage cut :  64.9
# Redshift Range - Training Subset
# average :  0.6051
# median :  0.5846
# minimum :  0.0010
# maximum :  7.0077
# Redshift Range - Validation Subset
# average :  0.7854
# median :  0.7761
# minimum :  0.0010
# maximum :  7.0112
# filter :  Data Selection
# Redshift Range Cut
# z min :  0.0000
# z max :  2.0000
# Magnitude used for cut :  auto
# Signal-to-noise Cut
# g :  None
# r :  None
# i :  None
# z :  None
# Y :  None
# Magnitude Limit Cut
# g :  None
# r :  None
# i :  22.5
# z :  None
# Y :  None
# Weights
# filter :
# Apply weights :  yes
# Weights only in validation :
# Size of virtual weighted set (how many times the main set size, when repeating objects) :  10.0
# Size of final weighted set (after random sampling in virtual set) :  1.0
# Observabes used to compute weights :  colors2
# Number of nearest neighbors uset to compute weights :  5
# Photo-z Training
# Training Files
# filter :
# Code :  training files created
# DNF :  photoz_train_1_._dnf_train_file.txt
# Code :  Duration
# DNF :  0.147 minutes
# Code :  Magnitude type
# DNF :  auto
# DNF
# Metrics DNF
# filter :  Global Metrics DNF
# Bias Mean :  0.0025
# Bias Median :  0.0069
# Sigma :  0.1607
# Sigma68 :  0.0885
# Frac 2 :  0.0202
# Frac 3 :  0.0076
# Bias norm :  0.0144
# Sigma norm :  1.1523
# N Poisson :  17.5547
# filter :  Metric Plots DNF
# Validation Plots DNF
# filter :  Validation Plots DNF
# Comparison
# Metrics
# filter :  Bias Mean
# DNF :  0.0025
# filter :  Sigma68
# DNF :  0.0885
# filter :  Frac above 2sigma
# DNF :  0.0202
# filter :  N Poisson
# DNF :  17.5547
