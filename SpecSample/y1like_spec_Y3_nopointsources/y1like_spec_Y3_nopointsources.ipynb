# %%
import xml.etree.ElementTree as ET
from IPython.core.display import Image, display
tree = ET.parse('productLog.xml')
root = tree.getroot()


for child in root:
    if 'name' in child.attrib:
        print child.attrib['name']
        if child.tag == 'statistics':
            for cx in child:
                if cx.text:
                    print cx.attrib['name'],': ',cx.text
                else:
                    print cx.attrib['name']
            
        elif child.tag == 'plot':
        
            print child[1].text

            display(Image(filename=child[0].text))
                        
            print child[2].text
            
        else:
            for ch in child:
                if 'name' in ch.attrib:
                    print ch.attrib['name']
                    if ch.tag == 'statistics':
                        for cx in ch:
                            if cx.text:
                                print cx.attrib['name'],': ',cx.text
                            else:
                                print cx.attrib['name']
                    
                    elif ch.tag == 'plot':
                        print ch[1].text

                        display(Image(filename=ch[0].text))
                        
                        print ch[2].text
                        
                    else:

                        for c in ch:
                            if c.tag == 'statistics':
                                for cx in c:
                                    if cx.text:
                                        print cx.attrib['name'],': ',cx.text
                                    else:
                                        print cx.attrib['name']
                            elif c.tag == 'plot':
                                print c[1].text

                                display(Image(filename=c[0].text))
                        
                                print c[2].text
                        
                            else:
                                print c.tag, ': ', c.attrib['name']
                                for cd in c:
                                    if cd.tag == 'plot':
                                        display(Image(filename=cd[0].text))
                                    elif cd.tag == 'statistics':
                                        for ds in cd:
                                            if ds.text:
                                                print ds.attrib['name'],': ',ds.text
                                            else:
                                                print ds.attrib['name']
                                #display(Image(filename=c[0].text))
# Out:
# Training Set Maker
# Summary
# SQL Statement
#
# filter :  Make join and correct magnitudes for zp
# filter :  Matching with the spectroscopic catalog
# filter :  Apply cuts in color, magnitudes and create table
# Training Set
#
# filter :  Statistics
# filter :
# filter :
# filter :  Plots
# filter :  Projected Distribution
# filter :  Redshift Distribution
# filter :  Number Counts
# filter :  Colors
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-1-0dd423e3720a> in <module>()
#      61                                 for cd in c:
#      62                                     if cd.tag == 'plot':
# ---> 63                                         display(Image(filename=cd[0].text))
#      64                                     elif cd.tag == 'statistics':
#      65                                         for ds in cd:
#
# /home/carnero/anaconda2/lib/python2.7/site-packages/IPython/core/display.pyc in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     737         self.unconfined = unconfined
#     738         self.metadata = metadata
# --> 739         super(Image, self).__init__(data=data, url=url, filename=filename)
#     740
#     741         if retina:
#
# /home/carnero/anaconda2/lib/python2.7/site-packages/IPython/core/display.pyc in __init__(self, data, url, filename)
#     384         self.filename = None if filename is None else unicode_type(filename)
#     385
# --> 386         self.reload()
#     387         self._check_data()
#     388
#
# /home/carnero/anaconda2/lib/python2.7/site-packages/IPython/core/display.pyc in reload(self)
#     759         """Reload the raw data from file or URL."""
#     760         if self.embed:
# --> 761             super(Image,self).reload()
#     762             if self.retina:
#     763                 self._retina_shape()
#
# /home/carnero/anaconda2/lib/python2.7/site-packages/IPython/core/display.pyc in reload(self)
#     402         """Reload the raw data from file or URL."""
#     403         if self.filename is not None:
# --> 404             with open(self.filename, self._read_flags) as f:
#     405                 self.data = f.read()
#     406         elif self.url is not None:
#
# IOError: [Errno 2] No such file or directory: u'matching_training_set_1_._color_iz.png'
